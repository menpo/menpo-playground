# %%
import shutil

# %%
shutil.make_archive('test', 'zip', './build/menpotoolbox/', '.')
# Out:
# '/Users/jab08/pythondev/menpotoolkit/test.zip'

# %%
shutil.make_archive('test', 'xztar', './build/menpotoolbox/', '.')
# Out:
# '/Users/jab08/pythondev/menpotoolkit/test.tar.xz'

# %%
'ada '.strip()
# Out:
# 'ada'

# %%
from menpotoolbox import build

# %%
build()
# Out:
# building menpotoolbox...
# >>> WHITELIST
# /Users/jab08/pythondev/menpotoolkit/build/miniconda/*
#  - .DS_Store
#  - bin/
#  - conda-meta/
#  - envs/
#  - include/
#  - lib/
#  - LICENSE.txt
#  - pkgs/
#  - python.app/
#  - share/
#  - ssl/
# >>> BLACKLIST
# /Users/jab08/pythondev/menpotoolkit/build/tmp_menpotoolbox/src/include
#  - include/
# /Users/jab08/pythondev/menpotoolkit/build/tmp_menpotoolbox/src/envs
#  - envs/
# /Users/jab08/pythondev/menpotoolkit/build/tmp_menpotoolbox/src/conda-meta
#  - conda-meta/
# /Users/jab08/pythondev/menpotoolkit/build/tmp_menpotoolbox/src/pkgs
#  - pkgs/
# /Users/jab08/pythondev/menpotoolkit/build/tmp_menpotoolbox/src/share
#  - share/
# /Users/jab08/pythondev/menpotoolkit/build/tmp_menpotoolbox/src/ssl
#  - ssl/
# /Users/jab08/pythondev/menpotoolkit/build/tmp_menpotoolbox/src/python*
#  - python.app/
# /Users/jab08/pythondev/menpotoolkit/build/tmp_menpotoolbox/src/bin/xml*
# /Users/jab08/pythondev/menpotoolkit/build/tmp_menpotoolbox/src/bin/q*
# ...
